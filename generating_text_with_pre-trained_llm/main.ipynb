# %% [markdown]
# ### Generating text with a pretrained llm

# %%
## here we will call the qwen model architecture
## and the download model

## move weights to respective layer

# %%
## will be here later
